# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
# constants and variables
EXPERIMENT = "experiment1"

TITLE = "Time v.s. Insertion Number"
Y_LABLE = "Time in milliseconds"
X_LABLE = "Length of insertions"

X = ["0.1M","0.2M","0.5M","0.8M","1M"]

# %%
# read files
treap, dummy = [], []

fp = open (EXPERIMENT + ".log", 'r')
for line in fp:
    if "Finsh" in line:
        time = line.rstrip().split('=')[-1]
        
        if "Treap" in line:
            treap.append(int(time))
        elif "Dummy" in line:
            dummy.append(int(time))
        
df = pd.DataFrame({ 'x':X, 'treap':treap, 'dummy':dummy })

# %%
treap
# Out:
# [220, 500, 1363, 2196, 2818]

# %%
dummy
# Out:
# [12, 31, 58, 96, 114]

# %%
# plot results
plt.rcParams["figure.dpi"] = 128
plt.rcParams['figure.figsize'] = 10, 5
plt.plot('x', 'treap', data=df, linewidth=1)
plt.plot('x', 'dummy', data=df, linewidth=1)
plt.title(TITLE)
plt.xlabel(X_LABLE)
plt.ylabel(Y_LABLE)
plt.legend(loc='upper left')
plt.show()
